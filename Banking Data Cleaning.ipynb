# %%
import pandas as pd

# %%
df = pd.read_csv('bank-additional-full.csv')

# %%
df.head()
# Out:
#   age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0  56;"housemaid";"married";"basic.4y";"no";"no";...
# 1  57;"services";"married";"high.school";"unknown...
# 2  37;"services";"married";"high.school";"no";"ye...
# 3  40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4  56;"services";"married";"high.school";"no";"no...

# %%
with open(file = 'bank-additional-full.csv', mode = 'r') as f:
    lis = [line.split(";") for line in f]

# %%
lis
# Out:
# [['"age"',
#   '"job"',
#   '"marital"',
#   '"education"',
#   '"default"',
#   '"housing"',
#   '"loan"',
#   '"contact"',
#   '"month"',
#   '"day_of_week"',
#   '"duration"',
#   '"campaign"',
#   '"pdays"',
#   '"previous"',
#   '"poutcome"',
#   '"emp.var.rate"',
#   '"cons.price.idx"',
#   '"cons.conf.idx"',
#   '"euribor3m"',
#   '"nr.employed"',
#   '"y"\n'],
#  ['56',
#   '"housemaid"',
#   '"married"',
#   '"basic.4y"',
#   '"no"',
#   '"no"',
#   '"no"',
#   '"telephone"',
#   '"may"',
#   '"mon"',
#   '261',
#   '1',
#   '999',
#   '0',
#   '"nonexistent"',
#   '1.1',
#   '93.994',
#   '-36.4',
#   '4.857',
#   '5191',
#   '"no"\n'],
#  ['57',
#   '"services"',
#   '"married"',
#   '"high.school"',
#   '"unknown"',
#   '"no"',
#   '"no"',
#   '"telephone"',
#   '"may"',
#   '"mon"',
#   '149',
#   '1',
#   '999',
#   '0',
#   '"nonexistent"',
#   '1.1',
#   '93.994',
#   '-36.4',
#   '4.857',
#   '5191',
#   '"no"\n'],
#  ['37',
#   '"services"',
#   '"married"',
# ...

# %%
df = pd.DataFrame(lis)

# %%
df
# Out:
#           0                1           2                      3          4   \
# 0      "age"            "job"   "marital"            "education"  "default"
# 1         56      "housemaid"   "married"             "basic.4y"       "no"
# 2         57       "services"   "married"          "high.school"  "unknown"
# 3         37       "services"   "married"          "high.school"       "no"
# 4         40         "admin."   "married"             "basic.6y"       "no"
# 5         56       "services"   "married"          "high.school"       "no"
# 6         45       "services"   "married"             "basic.9y"  "unknown"
# 7         59         "admin."   "married"  "professional.course"       "no"
# 8         41    "blue-collar"   "married"              "unknown"  "unknown"
# 9         24     "technician"    "single"  "professional.course"       "no"
# 10        25       "services"    "single"          "high.school"       "no"
# ...

# %%
df.describe()
# Out:
#            0         1          2                    3      4      5      6   \
# count   41189     41189      41189                41189  41189  41189  41189
# unique     79        13          5                    9      4      4      4
# top        31  "admin."  "married"  "university.degree"   "no"  "yes"   "no"
# freq     1947     10422      24928                12168  32588  21576  33950
#
#                 7      8      9   ...     11     12     13             14  \
# count        41189  41189  41189  ...  41189  41189  41189          41189
# unique           3     11      6  ...     43     28      9              4
# top     "cellular"  "may"  "thu"  ...      1    999      0  "nonexistent"
# freq         26144  13769   8623  ...  17642  39673  35563          35563
#
#            15      16     17     18      19      20
# count   41189   41189  41189  41189   41189   41189
# unique     11      27     27    317      12       3
# ...

# %%
df.columns = df.iloc[0]

# %%
df
# Out:
# 0      "age"            "job"   "marital"            "education"  "default"  \
# 0      "age"            "job"   "marital"            "education"  "default"
# 1         56      "housemaid"   "married"             "basic.4y"       "no"
# 2         57       "services"   "married"          "high.school"  "unknown"
# 3         37       "services"   "married"          "high.school"       "no"
# 4         40         "admin."   "married"             "basic.6y"       "no"
# 5         56       "services"   "married"          "high.school"       "no"
# 6         45       "services"   "married"             "basic.9y"  "unknown"
# 7         59         "admin."   "married"  "professional.course"       "no"
# 8         41    "blue-collar"   "married"              "unknown"  "unknown"
# 9         24     "technician"    "single"  "professional.course"       "no"
# 10        25       "services"    "single"          "high.school"       "no"
# ...

# %%
df = df.drop(df.index[0])

# %%
df
# Out:
# 0     "age"            "job"   "marital"            "education"  "default"  \
# 1        56      "housemaid"   "married"             "basic.4y"       "no"
# 2        57       "services"   "married"          "high.school"  "unknown"
# 3        37       "services"   "married"          "high.school"       "no"
# 4        40         "admin."   "married"             "basic.6y"       "no"
# 5        56       "services"   "married"          "high.school"       "no"
# 6        45       "services"   "married"             "basic.9y"  "unknown"
# 7        59         "admin."   "married"  "professional.course"       "no"
# 8        41    "blue-collar"   "married"              "unknown"  "unknown"
# 9        24     "technician"    "single"  "professional.course"       "no"
# 10       25       "services"    "single"          "high.school"       "no"
# 11       41    "blue-collar"   "married"              "unknown"  "unknown"
# ...

# %%
df.to_csv('banking.csv')
